# %%
import os
import glob
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.metrics import classification_report

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import drive
import os

# 1️⃣ Mount your Google Drive
drive.mount('/content/drive')
file_path = r'/content/drive/MyDrive/BloodGroupDataset/dataset/dataset_blood_group'

# List all classes in the dataset
name_class = os.listdir(file_path)
print(name_class)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['O+', 'O-', 'B+', 'B-', 'AB-', 'AB+', 'A+', 'A-']

# %%
# Get file paths for all images in the dataset
filepaths = list(glob.glob(file_path + '/**/*.*'))

# Example of printing a subset of file paths
print(filepaths[-6:-1])

# Extract labels from file paths
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))
print(labels)
# Out:
# ['/content/drive/MyDrive/BloodGroupDataset/dataset/dataset_blood_group/A-/cluster_1_1068.BMP', '/content/drive/MyDrive/BloodGroupDataset/dataset/dataset_blood_group/A-/cluster_1_1117.BMP', '/content/drive/MyDrive/BloodGroupDataset/dataset/dataset_blood_group/A-/cluster_1_1287.BMP', '/content/drive/MyDrive/BloodGroupDataset/dataset/dataset_blood_group/A-/cluster_1_1172.BMP', '/content/drive/MyDrive/BloodGroupDataset/dataset/dataset_blood_group/A-/cluster_1_1049.BMP']
# ['O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+ ...

# %%
# Create a DataFrame with file paths and labels
filepath = pd.Series(filepaths, name='Filepath').astype(str)
Labels = pd.Series(labels, name='Label')
data = pd.concat([filepath, Labels], axis=1)
data = data.sample(frac=1).reset_index(drop=True)
print(data.head(5))

# Visualize class distribution
counts = data.Label.value_counts()
sns.barplot(x=counts.index, y=counts)
plt.xlabel('Type')
plt.xticks(rotation=90)
plt.show()
# Out:
#                                             Filepath Label
# 0  /content/drive/MyDrive/BloodGroupDataset/datas...    B+
# 1  /content/drive/MyDrive/BloodGroupDataset/datas...   AB-
# 2  /content/drive/MyDrive/BloodGroupDataset/datas...   AB+
# 3  /content/drive/MyDrive/BloodGroupDataset/datas...    A+
# 4  /content/drive/MyDrive/BloodGroupDataset/datas...    O+

# %%
# Split data into training and testing sets
train, test = train_test_split(data, test_size=0.20, random_state=42)

# Visualize some images from the dataset
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(10, 8), subplot_kw={'xticks': [], 'yticks': []})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(data.Filepath[i]))
    ax.set_title(data.Label[i])
plt.tight_layout()
plt.show()

# %%
# Set up ImageDataGenerator for training and validation data
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_gen = train_datagen.flow_from_dataframe(
    dataframe=train,
    x_col='Filepath',
    y_col='Label',
    target_size=(256, 256),
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42
)

valid_gen = train_datagen.flow_from_dataframe(
    dataframe=test,
    x_col='Filepath',
    y_col='Label',
    target_size=(256, 256),
    class_mode='categorical',
    batch_size=32,
    shuffle=False,
    seed=42
)
# Out:
# Found 4800 validated image filenames belonging to 8 classes.
# Found 1200 validated image filenames belonging to 8 classes.

# %%
# Define the base pre-trained model
pretrained_model = ResNet50(
    input_shape=(256, 256, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

pretrained_model.trainable = False

# Add layers for classification on top of ResNet50
x = Dense(128, activation="relu")(pretrained_model.output)
x = Dense(128, activation="relu")(x)
outputs = Dense(8, activation='softmax')(x)

model = Model(inputs=pretrained_model.input, outputs=outputs)

model.compile(
    optimizer="adam",
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=20,
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 132s 783ms/step - accuracy: 0.4242 - loss: 1.4819 - val_accuracy: 0.6517 - val_loss: 0.8887
# Epoch 2/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 31s 209ms/step - accuracy: 0.6803 - loss: 0.8373 - val_accuracy: 0.7158 - val_loss: 0.7266
# Epoch 3/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 31s 204ms/step - accuracy: 0.7538 - loss: 0.6277 - val_accuracy: 0.7658 - val_loss: 0.5874
# Epoch 4/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 31s 203ms/step - accuracy: 0.7760 - loss: 0.5413 - val_accuracy: 0.7700 - val_loss: 0.6052
# Epoch 5/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 30s 202ms/step - accuracy: 0.8221 - loss: 0.4559 - val_accuracy: 0.8025 - val_loss: 0.5064
# Epoch 6/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 31s 204ms/step - accuracy: 0.8114 - loss: 0.4863 - val_accuracy: 0.7825 - val_loss: 0.5602
# Epoch 7/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 31s 203ms/step - accuracy: 0.8593 - loss: 0.3592 - val_accuracy: 0.7825 - val_loss: 0.5664
# Epoch 8/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 34s 225ms/step - accuracy: 0.8652 - loss: 0.3384 - val_accuracy: 0.7892 - val_loss: 0.5282
# Epoch 9/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 32s 210ms/step - accuracy: 0.8710 - loss: 0.3275 - val_accuracy: 0.8342 - val_loss: 0.4572
# Epoch 10/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 32s 214ms/step - accuracy: 0.8872 - loss: 0.2834 - val_accuracy: 0.8092 - val_loss: 0.5314
# Epoch 11/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 30s 200ms/step - accuracy: 0.9049 - loss: 0.2465 - val_accuracy: 0.8025 - val_loss: 0.5175
# Epoch 12/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 30s 201ms/step - accuracy: 0.8678 - loss: 0.3162 - val_accuracy: 0.7908 - val_loss: 0.6105
# Epoch 13/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 30s 201ms/step - accuracy: 0.9103 - loss: 0.2211 - val_accuracy: 0.8225 - val_loss: 0.4820
# Epoch 14/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 30s 199ms/step - accuracy: 0.9174 - loss: 0.2083 - val_accuracy: 0.8142 - val_loss: 0.5366
# Epoch 15/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 29s 196ms/step - accuracy: 0.9299 - loss: 0.1817 - val_accuracy: 0.8025 - val_loss: 0.5834
# Epoch 16/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 30s 200ms/step - accuracy: 0.9240 - loss: 0.1996 - val_accuracy: 0.8275 - val_loss: 0.5310
# Epoch 17/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 31s 204ms/step - accuracy: 0.9357 - loss: 0.1605 - val_accuracy: 0.8067 - val_loss: 0.5572
# Epoch 18/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 30s 203ms/step - accuracy: 0.9550 - loss: 0.1287 - val_accuracy: 0.8017 - val_loss: 0.5986
# Epoch 19/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 30s 203ms/step - accuracy: 0.9490 - loss: 0.1316 - val_accuracy: 0.7967 - val_loss: 0.7118
# Epoch 20/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 30s 200ms/step - accuracy: 0.9320 - loss: 0.1761 - val_accuracy: 0.8083 - val_loss: 0.6213

# %%
# Plot training history: accuracy
pd.DataFrame(history.history)[['accuracy', 'val_accuracy']].plot()
plt.title("Accuracy")
plt.show()

# Plot training history: loss
pd.DataFrame(history.history)[['loss', 'val_loss']].plot()
plt.title("Loss")
plt.show()

# Evaluate the model on test data
results = model.evaluate(valid_gen, verbose=0)
print(f"Test Loss: {results[0]:.5f}")
print(f"Test Accuracy: {results[1]*100:.2f}%")

# Predict labels for test data
pred = model.predict(valid_gen)
pred = np.argmax(pred, axis=1)

# Map predicted labels
labels = train_gen.class_indices
labels = dict((v, k) for k, v in labels.items())
pred = [labels[k] for k in pred]

# Compare predicted labels with true labels and print classification report
y_test = list(test.Label)
print(classification_report(y_test, pred))
# Out:
# Test Loss: 0.62131
# Test Accuracy: 80.83%
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 15s 277ms/step
#               precision    recall  f1-score   support
#
#           A+       0.79      0.96      0.87       118
#           A-       0.86      0.71      0.78       191
#          AB+       0.73      0.91      0.81       130
#          AB-       0.88      0.72      0.79       166
#           B+       0.82      0.83      0.83       125
#           B-       0.82      0.95      0.88       154
#           O+       0.84      0.74      0.78       182
#           O-       0.74      0.75      0.74       134
#
#     accuracy                           0.81      1200
#    macro avg       0.81      0.82      0.81      1200
# weighted avg       0.81      0.81      0.81      1200

# %%
model.save("model_blood_group_detection.h5")

# %%
train_gen.class_indices
# Out:
# {'A+': 0, 'A-': 1, 'AB+': 2, 'AB-': 3, 'B+': 4, 'B-': 5, 'O+': 6, 'O-': 7}

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import preprocess_input

# Load the pre-trained model
model = load_model('model_blood_group_detection.h5')

# Define the class labels
labels = {'A+': 0, 'A-': 1, 'AB+': 2, 'AB-': 3, 'B+': 4, 'B-': 5, 'O+': 6, 'O-': 7}
labels = dict((v, k) for k, v in labels.items())

# Example of loading a single image and making a prediction
img_path = '/content/drive/MyDrive/BloodGroupDataset/dataset/dataset_blood_group/A+/cluster_0_1026.BMP'

img = image.load_img(img_path, target_size=(256, 256))  # Load the image
x = image.img_to_array(img)  # Convert image to array
x = np.expand_dims(x, axis=0)  # Expand dimensions to match the model input
x = preprocess_input(x)  # Preprocess the image

result = model.predict(x)  # Predict using the model
predicted_class = np.argmax(result)  # Get the predicted class index

# Map the predicted class to the label
predicted_label = labels[predicted_class]
confidence = result[0][predicted_class] * 100  # Confidence level

# Display the image
plt.imshow(image.array_to_img(image.img_to_array(img) / 255.0))
plt.axis('off')  # Hide axes

# Display the prediction and confidence below the image
plt.title(f"Prediction: {predicted_label} with confidence {confidence:.2f}%")
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step

# %%
import matplotlib.pyplot as plt

plt.gcf().savefig("accuracy.png")
